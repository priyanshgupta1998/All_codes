# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshgupta1998/All_codes/blob/master/numpy4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Make the image without background

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
image = plt.imread('/home/green-fingerprint.jpg')
image.size
# Out:
# 3000000

# %%
image.shape
# Out:
# (1000, 1000, 3)

# %%
image
# Out:
# array([[[ 6,  6,  4],
#         [ 4,  4,  2],
#         [ 2,  2,  0],
#         ...,
#         [33, 43, 16],
#         [35, 44, 17],
#         [35, 44, 17]],
#
#        [[ 3,  3,  1],
#         [ 4,  4,  2],
#         [ 5,  5,  3],
#         ...,
#         [33, 43, 16],
#         [34, 44, 17],
#         [35, 45, 20]],
#
#        [[ 2,  2,  0],
#         [ 4,  4,  2],
#         [ 7,  7,  5],
#         ...,
#         [31, 45, 19],
#         [33, 46, 20],
#         [33, 46, 20]],
#
#        ...,
#
#        [[23, 25, 14],
#         [23, 25, 14],
#         [19, 21, 10],
#         ...,
#         [ 6,  4,  5],
#         [ 5,  3,  4],
#         [ 4,  2,  3]],
#
#        [[14, 16,  5],
#         [17, 19,  8],
#         [17, 19,  8],
#         ...,
#         [ 5,  3,  4],
#         [ 5,  3,  4],
#         [ 5,  3,  4]],
#
#        [[11, 13,  2],
#         [19, 21, 10],
#         [23, 25, 14],
#         ...,
#         [ 3,  1,  2],
#         [ 3,  1,  2],
#         [ 3,  1,  2]]], dtype=uint8)

# %%
time1 = time.time()
time1
# Out:
# 1550845863.6446028

# %% [markdown]
# ```
# #Built in vectorized function
# ```

# %%
image.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : False
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %% [markdown]
# ```
# the OWNDATA flag is set to False (which means the array borrows the memory from another object), as well as the WRITEABLE flag being False (this is why you can't change the object --> **image**).
#
# you does not create a new array in memory. Instead, you just get a view of the original data.
# ```

# %% [markdown]
# ```
# so we have  to create a copy of the array .(**image**)
# This gives the rgb image its own memory space, which can be changed without altering the 'image' .
# ```

# %%
image2 = image.copy()
image2[ image[:,:,1]<200] =0

# %%
a = np.array([[1,2,3],[4,5,6]])
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a>=3
# Out:
# array([[False, False,  True],
#        [ True,  True,  True]])

# %%
a[a>=3]
# Out:
# array([3, 4, 5, 6])

# %%
time2 = time.time()

# %%
time_diff = (time2-time1)
time_diff
# Out:
# 184.42210817337036

# %%
time3 = time.time()  # again start the time for the next process

# %%
image2[0].shape
# Out:
# (1000, 3)

# %%
image2.shape[0]
# Out:
# 1000

# %%
image2.shape[1]
# Out:
# 1000

# %%
image2.shape[2]
# Out:
# 3

# %%
for i in range(0 , image2.shape[0]):
  for k in range(0 , image2.shape[1]):
    if image2[i,k,1]<200:
      image2[i,k,1]=0

# %%
time4 =time.time()      # ending time of the process2

# %%
timeloop = (time4- time3)
timeloop
# Out:
# 255.30717420578003

# %%
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
plt.imshow(image2)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
from PIL import Image
img = np.array(Image.open('/home/green-fingerprint.jpg'))
plt.imshow(img)
