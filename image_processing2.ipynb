# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshgupta1998/All_codes/blob/master/image_processing2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Image processing

# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
image_name = '/home/make/lena.png'
image_name
# Out:
# '/home/make/lena.png'

# %%
im_data = img.imread(image_name)

# %%
im_data.shape    # IT will print the colors (R,G,B)
# Out:
# (220, 220, 3)

# %%
im_data[0].shape
# Out:
# (220, 3)

# %%
im_data[0]
# Out:
# array([[0.88235295, 0.5372549 , 0.49803922],
#        [0.8784314 , 0.5372549 , 0.49803922],
#        [0.8901961 , 0.5254902 , 0.46666667],
#        [0.8901961 , 0.5411765 , 0.49019608],
#        [0.8862745 , 0.5294118 , 0.47843137],
#        [0.88235295, 0.5254902 , 0.45490196],
#        [0.87058824, 0.52156866, 0.4509804 ],
#        [0.8666667 , 0.5254902 , 0.44705883],
#        [0.8745098 , 0.5294118 , 0.44705883],
#        [0.8745098 , 0.50980395, 0.40392157],
#        [0.8627451 , 0.52156866, 0.43529412],
#        [0.8745098 , 0.5058824 , 0.41568628],
#        [0.8666667 , 0.5019608 , 0.4509804 ],
#        [0.87058824, 0.5058824 , 0.43529412],
#        [0.88235295, 0.50980395, 0.41960785],
#        [0.8784314 , 0.5294118 , 0.45882353],
#        [0.8980392 , 0.54901963, 0.4509804 ],
#        [0.90588236, 0.5568628 , 0.45490196],
#        [0.9098039 , 0.57254905, 0.4627451 ],
#        [0.92156863, 0.59607846, 0.48235294],
#        [0.91764706, 0.5882353 , 0.47058824],
# ...

# %%
im_data.size    # 355*355*3
# Out:
# 145200

# %%
im_data[0].size   #355*3
# Out:
# 660

# %%
im_data
# Out:
# array([[[0.88235295, 0.5372549 , 0.49803922],
#         [0.8784314 , 0.5372549 , 0.49803922],
#         [0.8901961 , 0.5254902 , 0.46666667],
#         ...,
#         [0.8901961 , 0.5529412 , 0.5019608 ],
#         [0.9098039 , 0.5882353 , 0.4862745 ],
#         [0.8352941 , 0.47058824, 0.40784314]],
#
#        [[0.88235295, 0.5372549 , 0.49803922],
#         [0.8784314 , 0.53333336, 0.49803922],
#         [0.8901961 , 0.5254902 , 0.46666667],
#         ...,
#         [0.9019608 , 0.5647059 , 0.50980395],
#         [0.93333334, 0.60784316, 0.49411765],
#         [0.85882354, 0.4862745 , 0.4117647 ]],
#
#        [[0.8901961 , 0.5372549 , 0.47843137],
#         [0.8784314 , 0.5254902 , 0.4627451 ],
#         [0.89411765, 0.52156866, 0.45882353],
#         ...,
#         [0.81960785, 0.44313726, 0.41568628],
#         [0.7411765 , 0.38039216, 0.3764706 ],
#         [0.58431375, 0.23921569, 0.3137255 ]],
#
#        ...,
#
#        [[0.3529412 , 0.10980392, 0.23529412],
# ...

# %%
np.shape(im_data)
# Out:
# (220, 220, 3)

# %%
plt.figure(figsize=(15,15))

# %%
cmap = 'hot'

# %%
plt.imshow(im_data , cmap = cmap , interpolation = 'nearest')

# %%
plt.imshow(im_data , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
# Out:
# (-0.5, 219.5, 219.5, -0.5)

# %%
plt.imshow(im_data , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('Original image in RGB')
# Out:
# Text(0.5, 1.0, 'Original image in RGB')

# %%
red_data = im_data[:,:,0]
red_data
# Out:
# array([[0.88235295, 0.8784314 , 0.8901961 , ..., 0.8901961 , 0.9098039 ,
#         0.8352941 ],
#        [0.88235295, 0.8784314 , 0.8901961 , ..., 0.9019608 , 0.93333334,
#         0.85882354],
#        [0.8901961 , 0.8784314 , 0.89411765, ..., 0.81960785, 0.7411765 ,
#         0.58431375],
#        ...,
#        [0.3529412 , 0.37254903, 0.38039216, ..., 0.49411765, 0.5803922 ,
#         0.61960787],
#        [0.34117648, 0.36078432, 0.37254903, ..., 0.56078434, 0.654902  ,
#         0.6627451 ],
#        [0.32941177, 0.37254903, 0.3647059 , ..., 0.62352943, 0.6901961 ,
#         0.7137255 ]], dtype=float32)

# %%
red_data.size
# Out:
# 48400

# %%
red_data.shape
# Out:
# (220, 220)

# %%
green_data = im_data[:,:,1]
green_data
# Out:
# array([[0.5372549 , 0.5372549 , 0.5254902 , ..., 0.5529412 , 0.5882353 ,
#         0.47058824],
#        [0.5372549 , 0.53333336, 0.5254902 , ..., 0.5647059 , 0.60784316,
#         0.4862745 ],
#        [0.5372549 , 0.5254902 , 0.52156866, ..., 0.44313726, 0.38039216,
#         0.23921569],
#        ...,
#        [0.10980392, 0.11372549, 0.10980392, ..., 0.16470589, 0.22745098,
#         0.23137255],
#        [0.09411765, 0.10588235, 0.09803922, ..., 0.22745098, 0.2627451 ,
#         0.25490198],
#        [0.08627451, 0.11372549, 0.09411765, ..., 0.2627451 , 0.27450982,
#         0.2784314 ]], dtype=float32)

# %%
green_data.size
# Out:
# 48400

# %%
green_data.shape
# Out:
# (220, 220)

# %%
blue_data = im_data[:,:,2]
blue_data
# Out:
# array([[0.49803922, 0.49803922, 0.46666667, ..., 0.5019608 , 0.4862745 ,
#         0.40784314],
#        [0.49803922, 0.49803922, 0.46666667, ..., 0.50980395, 0.49411765,
#         0.4117647 ],
#        [0.47843137, 0.4627451 , 0.45882353, ..., 0.41568628, 0.3764706 ,
#         0.3137255 ],
#        ...,
#        [0.23529412, 0.23921569, 0.24705882, ..., 0.26666668, 0.28627452,
#         0.28627452],
#        [0.23921569, 0.24313726, 0.23921569, ..., 0.30588236, 0.3137255 ,
#         0.30588236],
#        [0.22745098, 0.24313726, 0.23137255, ..., 0.32941177, 0.31764707,
#         0.3137255 ]], dtype=float32)

# %%
blue_data.shape
# Out:
# (220, 220)

# %%
blue_data.size
# Out:
# 48400

# %% [markdown]
# Now change the dimensions of the image
#
# ```
# change the color orders
# ```

# %% [markdown]
# #Convert into GREEN  ( GRB)

# %%
image1 = np.array([ green_data , red_data,blue_data ])

# %%
image1 = np.swapaxes(image1 , 0 ,1)
#image1

# %%
image1 = np.swapaxes(image1 , 1,2)

# %%
np.shape(image1)
# Out:
# (220, 220, 3)

# %%
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(231)
plt.imshow(im_data , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('Original image in RGB')
# Out:
# Text(0.5, 1.0, 'Original image in RGB')

# %%
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(232)
plt.imshow(image1 , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('Original image in RGB')
# Out:
# Text(0.5, 1.0, 'Original image in RGB')

# %% [markdown]
# #Convert into BLUE (BGR)

# %%
image2 = np.array([blue_data, green_data , red_data ])
image2 = np.swapaxes(image2 , 0 ,1)
image2 = np.swapaxes(image2  , 1,2)
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(232)
plt.imshow(image2  , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
# Out:
# (-0.5, 219.5, 219.5, -0.5)

# %% [markdown]
# #Light Green ( BRG)

# %%
image3 = np.array([blue_data, red_data, green_data  ])
image3  = np.swapaxes(image3  , 0 ,1)
image3  = np.swapaxes(image3  , 1,2)
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(232)
plt.imshow(image3  , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('Original image in RGB')
# Out:
# Text(0.5, 1.0, 'Original image in RGB')

# %% [markdown]
# # RBG

# %%
image4 = np.array([ red_data, blue_data,green_data  ])
image4= np.swapaxes(image4 , 0 ,1)
image4 = np.swapaxes(image4 , 1,2)
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(232)
plt.imshow(image4 , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('Original image in RGB')
# Out:
# Text(0.5, 1.0, 'Original image in RGB')

# %% [markdown]
# # Different type of coloured image

# %%
image5 = np.array([red_data , 256*green_data, 256*blue_data  ])
image5 = np.swapaxes(image5  , 0 ,1)
image5  = np.swapaxes(image5  , 1,2)
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(232)
plt.imshow(image5 , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('Original image in RGB')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Original image in RGB')

# %% [markdown]
# #image with specific background

# %%
image6 = np.array([ 1.0*green_data, 0.5*red_data , 0.5*blue_data  ])
#image6 = np.array([(1.5*green_data)%256 ,(0.5*red_data)%256,(0.5*blue_data)%256 ]).astype(np.uint8)
image6 = np.swapaxes(image6 , 0 ,1)
image6  = np.swapaxes(image6  , 1,2)
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(232)
plt.imshow(image6 , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('Original image in RGB')
# Out:
# Text(0.5, 1.0, 'Original image in RGB')

# %%
image6 = np.array([ 3.5*green_data, 1.0*red_data , 1.5*blue_data  ])
image6 = np.swapaxes(image6 , 0 ,1)
image6  = np.swapaxes(image6  , 1,2)
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(232)
plt.imshow(image6 , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('Original image in RGB')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Original image in RGB')

# %%
image6 = np.array([ 7.5*green_data, 2.5*red_data , 2.2*blue_data  ])
image6 = np.swapaxes(image6 , 0 ,1)
image6  = np.swapaxes(image6  , 1,2)
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(232)
plt.imshow(image6 , cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('Original image in RGB')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Original image in RGB')

# %%
#cmap = 'gray'
cmap = 'hot'
plt.figure(figsize = (15,10))
plt.subplot(233)
plt.imshow(red_data, cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('red data')
plt.colorbar()

# %%
cmap = 'hot'
#cmap = 'gray'
plt.figure(figsize = (15,10))
plt.subplot(233)
plt.imshow(green_data, cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('green data')
plt.colorbar()

# %%
cmap = 'hot'
#cmap = 'gray'
plt.figure(figsize = (15,10))
plt.subplot(233)
plt.imshow(blue_data, cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('blue data')
plt.colorbar()

# %%
cmap = 'jet'
plt.figure(figsize = (15,10))
plt.subplot(233)
plt.imshow(red_data, cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('blue data')
plt.colorbar()

# %%
cmap = 'jet'
plt.figure(figsize = (15,10))
plt.subplot(233)
plt.imshow(green_data, cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('blue data')
plt.colorbar()

# %%
cmap = 'jet'
plt.figure(figsize = (15,10))
plt.subplot(233)
plt.imshow(blue_data, cmap = cmap , interpolation = 'nearest')
plt.axis('off')
plt.title('blue data')
plt.colorbar()

# %%
plt.figure(figsize = (15,10))
plt.subplot(131)
plt.hist(red_data.ravel() , bins = 100 , ec='k')
plt.subplot(132)
plt.hist(green_data.ravel() , bins = 100 , ec='k')
plt.subplot(133)
plt.hist(blue_data.ravel() , bins = 100 , ec='k')
# Out:
# (array([2.000e+00, 3.000e+00, 3.000e+00, 6.000e+00, 2.200e+01, 7.100e+01,
#         1.350e+02, 9.600e+01, 3.220e+02, 5.320e+02, 7.670e+02, 4.720e+02,
#         1.136e+03, 1.273e+03, 1.205e+03, 5.250e+02, 9.690e+02, 9.720e+02,
#         1.070e+03, 5.810e+02, 1.270e+03, 1.199e+03, 1.137e+03, 5.330e+02,
#         1.016e+03, 1.027e+03, 5.080e+02, 1.049e+03, 1.121e+03, 1.113e+03,
#         5.750e+02, 1.235e+03, 1.116e+03, 1.045e+03, 5.140e+02, 9.120e+02,
#         9.310e+02, 9.950e+02, 5.210e+02, 1.041e+03, 1.032e+03, 9.440e+02,
#         5.030e+02, 9.790e+02, 1.050e+03, 1.221e+03, 6.260e+02, 1.224e+03,
#         1.043e+03, 4.270e+02, 7.670e+02, 6.060e+02, 4.040e+02, 1.970e+02,
#         3.160e+02, 3.320e+02, 3.090e+02, 1.550e+02, 3.050e+02, 3.000e+02,
#         3.130e+02, 1.620e+02, 2.880e+02, 3.100e+02, 3.310e+02, 1.970e+02,
#         4.100e+02, 3.410e+02, 3.370e+02, 1.860e+02, 3.230e+02, 3.040e+02,
#         2.900e+02, 1.450e+02, 2.580e+02, 2.840e+02, 1.140e+02, 2.000e+02,
# ...
